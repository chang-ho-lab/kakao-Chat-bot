# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc

import matplotlib

font_location='c:/Windows/fonts/malgun.ttf' 

font_name=font_manager.FontProperties(fname=font_location).get_name()

matplotlib.rc('font',family=font_name)

# %%
df=pd.read_csv('경기임대.csv',encoding='euc-kr')
df
# Out:
#        시군명   기관명           단지명        준공일자  공급유형명  형명  세대수  공급전용면적(㎡)  \
# 0      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  33  335      33.13
# 1      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  41  335      41.05
# 2      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  51  335      51.64
# 3      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  51  335      51.45
# 4      가평군  LH서울     가평읍내주공아파트  19991116.0  50년임대  39  355      39.51
# ...    ...   ...           ...         ...    ...  ..  ...        ...
# 15190  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  36  649      36.99
# 15191  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  46  649      46.90
# 15192  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  46  649      46.70
# 15193  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  51  649      51.93
# 15194  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  59  649      59.89
#
#        공급공용면적(㎡) 도로명주소                             지번주소     우편번호         위도  \
# ...

# %%
city=df['세대수'].value_counts()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15195 entries, 0 to 15194
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시군명        15195 non-null  object
#  1   기관명        15195 non-null  object
#  2   단지명        15195 non-null  object
#  3   준공일자       1959 non-null   float64
#  4   공급유형명      15195 non-null  object
#  5   형명         14992 non-null  object
#  6   세대수        15195 non-null  int64
#  7   공급전용면적(㎡)  15194 non-null  float64
#  8   공급공용면적(㎡)  15186 non-null  float64
#  9   도로명주소      10105 non-null  object
#  10  지번주소       15195 non-null  object
#  11  우편번호       15193 non-null  float64
#  12  위도         15193 non-null  float64
#  13  경도         15193 non-null  float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['시군명', '기관명', '단지명', '준공일자', '공급유형명', '형명', '세대수', '공급전용면적(㎡)',
#        '공급공용면적(㎡)', '도로명주소', '지번주소', '우편번호', '위도', '경도'],
#       dtype='object')

# %%
df['시군명'].value_counts()
# Out:
# 수원시     2388
# 안산시     1914
# 용인시     1124
# 고양시     1033
# 부천시     1000
# 의정부시     836
# 평택시      831
# 남양주시     816
# 화성시      600
# 성남시      534
# 시흥시      397
# 파주시      390
# 안양시      321
# 군포시      312
# 김포시      287
# 오산시      283
# 양주시      271
# 포천시      261
# 동두천시     238
# 광주시      214
# 안성시      210
# 의왕시      192
# 여주시      166
# 이천시      154
# 광명시      126
# 하남시      104
# 연천군       64
# 구리시       61
# 가평군       43
# 양평군       22
# 과천시        3
# Name: 시군명, dtype: int64

# %%
df[df['시군명']=='수원시'][['시군명','공급유형명']]
# Out:
#       시군명  공급유형명
# 4667  수원시   매입임대
# 4668  수원시   매입임대
# 4669  수원시   매입임대
# 4670  수원시   매입임대
# 4671  수원시   매입임대
# ...   ...    ...
# 7050  수원시   국민임대
# 7051  수원시   국민임대
# 7052  수원시   국민임대
# 7053  수원시  10년임대
# 7054  수원시  10년임대
#
# [2388 rows x 2 columns]

# %%
df['공급유형명'].value_counts()
# Out:
# 매입임대     12994
# 국민임대      1092
# 10년임대      692
# 행복주택       269
# 영구임대       101
# 50년임대       27
# 장기전세        12
# 5년임대         8
# Name: 공급유형명, dtype: int64

# %%
df
# Out:
#        시군명   기관명           단지명        준공일자  공급유형명  형명  세대수  공급전용면적(㎡)  \
# 0      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  33  335      33.13
# 1      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  41  335      41.05
# 2      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  51  335      51.64
# 3      가평군  LH서울  가평읍내 휴먼시아2단지  20100830.0   국민임대  51  335      51.45
# 4      가평군  LH서울     가평읍내주공아파트  19991116.0  50년임대  39  355      39.51
# ...    ...   ...           ...         ...    ...  ..  ...        ...
# 15190  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  36  649      36.99
# 15191  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  46  649      46.90
# 15192  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  46  649      46.70
# 15193  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  51  649      51.93
# 15194  화성시  LH경기      휴먼시아 1단지  20110322.0   국민임대  59  649      59.89
#
#        공급공용면적(㎡) 도로명주소                             지번주소     우편번호         위도  \
# ...

# %%
df[df['공급유형명']=='10년임대']
# Out:
#        시군명   기관명           단지명        준공일자  공급유형명  형명   세대수  공급전용면적(㎡)  \
# 67     고양시  LH인천  고양향동지구 S-1블록  20190701.0  10년임대  51  1521      51.96
# 68     고양시  LH인천  고양향동지구 S-1블록  20190701.0  10년임대  59  1521      59.59
# 69     고양시  LH인천  고양향동지구 S-1블록  20190701.0  10년임대  59  1521      59.92
# 70     고양시  LH인천  고양향동지구 S-1블록  20190701.0  10년임대  74  1521      74.90
# 71     고양시  LH인천  고양향동지구 S-1블록  20190701.0  10년임대  74  1521      74.49
# ...    ...   ...           ...         ...    ...  ..   ...        ...
# 15159  화성시  LH경기   화성동탄2 A81블록  20200801.0  10년임대  59     1      59.95
# 15160  화성시  LH경기   화성동탄2 A81블록  20200801.0  10년임대  59     1      59.95
# 15161  화성시  LH경기   화성동탄2 A81블록  20200801.0  10년임대  74   867      74.95
# 15162  화성시  LH경기   화성동탄2 A81블록  20200801.0  10년임대  84   867      84.92
# 15163  화성시  LH경기   화성동탄2 A81블록  20200801.0  10년임대  84     3      84.92
#
#        공급공용면적(㎡)                 도로명주소  \
# 67        19.294                   NaN
# ...

# %%
df_1=df[df['공급유형명']=='행복주택']
df_1
# Out:
#        시군명   기관명                    단지명        준공일자 공급유형명  형명  세대수  공급전용면적(㎡)  \
# 50     고양시  LH인천          고양지축 행복주택 A-3  20181123.0  행복주택  16  890      16.65
# 51     고양시  LH인천          고양지축 행복주택 A-3  20181123.0  행복주택  26  890      26.64
# 52     고양시  LH인천          고양지축 행복주택 A-3  20181123.0  행복주택  26  890      26.62
# 53     고양시  LH인천          고양지축 행복주택 A-3  20181123.0  행복주택  36  890      36.63
# 54     고양시  LH인천        고양향동 A-4블록 행복주택  20200607.0  행복주택  16  498      16.23
# ...    ...   ...                    ...         ...   ...  ..  ...        ...
# 15184  화성시  LH경기     화성봉담2 A-6(4단지)(행복)  20190730.0  행복주택  36  602      36.38
# 15185  화성시  LH경기     화성봉담2 A-6(4단지)(행복)  20190730.0  행복주택  36  602      36.24
# 15186  화성시  LH경기  화성향남2 A20블럭(20단지)(행복)  20190712.0  행복주택  16   99      16.06
# 15187  화성시  LH경기  화성향남2 A20블럭(20단지)(행복)  20190712.0  행복주택  26   99      26.36
# 15188  화성시  LH경기  화성향남2 A20블럭(20단지)(행복)  20190712.0  행복주택  36   99      36.15
#
# ...

# %%
df_1=df_1[['시군명','세대수']]
df_1
# Out:
#        시군명  세대수
# 50     고양시  890
# 51     고양시  890
# 52     고양시  890
# 53     고양시  890
# 54     고양시  498
# ...    ...  ...
# 15184  화성시  602
# 15185  화성시  602
# 15186  화성시   99
# 15187  화성시   99
# 15188  화성시   99
#
# [269 rows x 2 columns]

# %%
df_1['시군명'].value_counts()
# Out:
# 화성시     83
# 고양시     20
# 양주시     19
# 평택시     18
# 파주시     17
# 오산시     16
# 의정부시    14
# 김포시     13
# 시흥시     10
# 남양주시     9
# 성남시      9
# 하남시      8
# 부천시      8
# 의왕시      5
# 용인시      5
# 이천시      4
# 안성시      4
# 군포시      4
# 수원시      3
# Name: 시군명, dtype: int64

# %%
type(df_1['시군명'].value_counts())
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,9))
plt.plot(df_1['시군명'].value_counts(),marker='o')
plt.title('경기도 내 행복주택',size=20)
plt.xlabel('시군명',size=20)
plt.ylabel('행복주택 수',size=20)
plt.grid(alpha=0.5)
plt.xticks(rotation=45)
plt.yticks()
plt.legend(fontsize=20)
plt.show()
# Out:
# No handles with labels found to put in legend.
